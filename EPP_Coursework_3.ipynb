# %% [markdown]
# #Coursework 3

# %% [markdown]
# ##Coursework Code Tests

# %%
# !pip install astropy
from astropy.io import ascii
import numpy as np
from matplotlib import pyplot as plt
import statistics

# %%
dataarray = ascii.read("https://raw.githubusercontent.com/Hamza-Suleman/EPP-Coursework3/main/datafile.csv")
print(dataarray)
# Out:
# Event   mu_E    mu_Px     mu_Py   ...   J3_E    J3_Px    J3_Py     J3_Pz
# ----- -------- -------- --------- ... -------- -------- -------- ---------
#     0  51268.2  23427.4  -30694.4 ...  62572.0 -33733.8 -15020.8  -50334.6
#     8  62607.2 -55928.2  -27403.4 ...  31804.9 -28743.6  11803.6  -203.991
#    41 175318.0 110076.0 -128700.0 ...  68410.5  8936.84  32453.5   59377.2
#    44 125126.0  32677.8  102847.0 ... 112722.0  19212.2 -19288.7 -109245.0
#    52  81170.1  45960.6  -38977.6 ...  55170.7  9476.58 -26691.3   46793.3
#    54  57112.3 -27548.2  -11543.4 ...  77868.8 -13785.2 -22157.4   73276.7
#   100  64891.5 -22903.1  -44698.0 ... 160494.0 -20458.6 -25679.6 -156987.0
#   113  78314.0  22202.4  -56183.6 ...  46334.9  21388.2  13032.1  -38665.0
#   123 190124.0 -81916.9   85738.1 ... 144231.0  32883.8 -13119.1  139745.0
#   131  71425.3 -39384.6   5885.81 ...  38197.5 -31740.0  5191.16  -20362.3
#   ...      ...      ...       ... ...      ...      ...      ...       ...
# ...

# %%
test = []
for i in range(len(dataarray)):
  a = np.sqrt((dataarray[i]["J1_E"]+dataarray[i]["J2_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J2_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J2_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J2_Pz'])**2)/1000
  if abs(a-80)<40:
    test.append(a)
print(np.mean(test))
# Out:
# 81.18074164591046

# %% [markdown]
# ###Calculating m12

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m12 = np.sqrt((line[13]+line[17])**2 - (line[14]+line[18])**2 - (line[15]+line[19])**2 - (line[16]+line[20])**2)/1000

    if abs(m12-80)<40:
            mwlist.append(m12)

m12mean = np.mean(mwlist)
print('Mean: ', m12mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m12mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  81.18074164591046
# Standard Deviation:  15.046417344366949

# %% [markdown]
# ###Calculating m13

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m13 = np.sqrt((line[13]+line[21])**2 - (line[14]+line[22])**2 - (line[15]+line[23])**2 - (line[16]+line[24])**2)/1000

    if abs(m13-80)<40:
            mwlist.append(m13)

m13mean = np.mean(mwlist)
print('Mean: ', m13mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m13mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  81.68432650356482
# Standard Deviation:  15.422884128354791

# %% [markdown]
# ###Calculating m23

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m23 = np.sqrt((line[17]+line[21])**2 - (line[18]+line[22])**2 - (line[19]+line[23])**2 - (line[20]+line[24])**2)/1000

    if abs(m23-80)<40:
            mwlist.append(m23)

m23mean = np.mean(mwlist)
print('Mean: ', m23mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m23mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  78.58913503350712
# Standard Deviation:  15.153927556263104

# %% [markdown]
# ###B1J1

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j1 = np.sqrt((line[5]+line[13])**2 - (line[6]+line[14])**2 - (line[7]+line[15])**2 - (line[8]+line[16])**2)/1000

    if abs(b1j1-80)<40:
            bjlist.append(b1j1)

b1j1mean = np.mean(bjlist)
print('Mean: ', b1j1mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j1mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  90.83047729463615
# Standard Deviation:  17.987816638946153

# %% [markdown]
# ###B1J2

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j2 = np.sqrt((line[5]+line[17])**2 - (line[6]+line[18])**2 - (line[7]+line[19])**2 - (line[8]+line[20])**2)/1000

    if abs(b1j2-80)<40:
            bjlist.append(b1j2)

b1j2mean = np.mean(bjlist)
print('Mean: ', b1j2mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j2mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  91.22513891585919
# Standard Deviation:  17.866354790987412

# %% [markdown]
# ###B1J3

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j3 = np.sqrt((line[5]+line[21])**2 - (line[6]+line[22])**2 - (line[7]+line[23])**2 - (line[8]+line[24])**2)/1000

    if abs(b1j3-80)<40:
            bjlist.append(b1j3)

b1j3mean = np.mean(bjlist)
print('Mean: ', b1j3mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j3mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  84.54153630588095
# Standard Deviation:  17.48440626508665

# %% [markdown]
# ###B2J1

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j1 = np.sqrt((line[9]+line[13])**2 - (line[10]+line[14])**2 - (line[11]+line[15])**2 - (line[12]+line[16])**2)/1000

    if abs(b2j1-80)<40:
            bjlist.append(b2j1)

b2j1mean = np.mean(bjlist)
print('Mean: ', b2j1mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j1mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  90.56881516259845
# Standard Deviation:  18.252261505498097

# %% [markdown]
# ###B2J2

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j2 = np.sqrt((line[9]+line[17])**2 - (line[10]+line[18])**2 - (line[11]+line[19])**2 - (line[12]+line[20])**2)/1000

    if abs(b2j2-80)<40:
            bjlist.append(b2j2)

b2j2mean = np.mean(bjlist)
print('Mean: ', b2j2mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j2mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  85.62474233223087
# Standard Deviation:  18.102068393210754

# %% [markdown]
# ###B2J3

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j3 = np.sqrt((line[9]+line[21])**2 - (line[10]+line[22])**2 - (line[11]+line[23])**2 - (line[12]+line[24])**2)/1000

    if abs(b2j3-80)<40:
            bjlist.append(b2j3)

b2j3mean = np.mean(bjlist)
print('Mean: ', b2j3mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j3mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  80.62244065022391
# Standard Deviation:  16.73753717132416

# %% [markdown]
# ###B1B2

# %%
bblist = []
print(bblist)
for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1b2 = np.sqrt((line[5]+line[9])**2 - (line[6]+line[10])**2 - (line[7]+line[11])**2 - (line[8]+line[12])**2)/1000

    if abs(b1b2-80)<40:
            bblist.append(b1b2)

b1b2mean = np.mean(bblist)
print('Mean: ', b1b2mean)
print("Standard Deviation: ", (statistics.stdev(bblist)/100)*b1b2mean)
          
plt.hist(bblist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# []
# Mean:  86.40246153365707
# Standard Deviation:  17.071979226406135

# %% [markdown]
# ###Muon Mass

# %%
muon_mass_list = []
for i in range(len(dataarray)):
  a = np.sqrt(abs(((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2)))/1000
  muon_mass_list.append(a)
muon_mass = np.mean(muon_mass_list)
print("Muon Mass: ", muon_mass)
print("Standard Deviation: ", (statistics.stdev(muon_mass_list)/100)*muon_mass)
# Out:
# Muon Mass:  0.18785128321912073
# Standard Deviation:  0.0002796983198460747

# %% [markdown]
# ###Top Quark Mass

# %%
jet_mass = m12mean+m13mean+m23mean
print(jet_mass)
# Out:
# 241.4542031829824

# %%
b_j_mass = b1b2mean + (jet_mass/3)
print(b_j_mass)
# Out:
# 166.88719592798455

# %%
top_mass = b_j_mass + muon_mass
print(top_mass)
print()
# Out:
# 167.07504721120367

# %%
print(m12mean-muon_mass+b1b2mean)
# Out:
# 167.39535189634842

# %%
print(m13mean-muon_mass+b1b2mean)
# Out:
# 167.89893675400276

# %%
print(m23mean-muon_mass+b1b2mean)
# Out:
# 164.8037452839451

# %%
print(b1j1mean+muon_mass)
# Out:
# 91.01832857785527

# %%
print(m12mean+b1b2mean)
# Out:
# 167.58320317956753

# %%
print(m13mean+b1b2mean)
# Out:
# 168.08678803722188

# %%
print(m23mean+b1b2mean)
# Out:
# 164.9915965671642

# %%
print(b1j1mean+b1j2mean+b1j3mean)
# Out:
# 266.5971525163763

# %%
print(b1b2mean+m12mean+muon_mass)
# Out:
# 167.77105446278665

# %%
print(b1b2mean+m13mean+muon_mass)
# Out:
# 168.274639320441

# %%
print(b1b2mean+m23mean+muon_mass)
# Out:
# 165.17944785038333

# %% [markdown]
# ##Graphing

# %%
b1b2j1j2muon = b1b2mean + m12mean + muon_mass_list
plt.hist(b1b2j1j2muon, bins=100, range=(165,180), label="m(T) [GeV]",alpha=0.8,color="b")
plt.title("A range of top quark values for a combination of B1B2, J1J2 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.savefig("j1j2.png")
plt.show()
print('Mean: ', np.mean(b1b2j1j2muon))
print("Standard Deviation: ", np.std(b1b2j1j2muon))
# Out:
# Mean:  167.77105446278665
# Standard Deviation:  0.14872758566222072

# %%
b1b2j1j3muon = b1b2mean + m13mean + muon_mass_list
plt.hist(b1b2j1j3muon, bins=100, range=(165,180), label="m(T) [GeV]",alpha=0.8,color="r") 
plt.title("A range of top quark values for a combination of B1B2, J1J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.savefig("j1j3.png")
plt.show()
print('Mean: ', np.mean(b1b2j1j3muon))
print("Standard Deviation: ", np.std(b1b2j1j3muon))
# Out:
# Mean:  168.27463932044103
# Standard Deviation:  0.1487275856622207

# %%
b1b2j2j3muon = b1b2mean + m23mean + muon_mass_list
plt.hist(b1b2j2j3muon, bins=100, range=(165,180), label="m(T) [GeV]",alpha=0.8,color="g") 
plt.title("A range of top quark values for a combination of B1B2, J2J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.savefig("j2j3.png")
plt.show()
print('Mean: ', np.mean(b1b2j2j3muon))
print("Standard Deviation: ", np.std(b1b2j2j3muon))
# Out:
# Mean:  165.17944785038335
# Standard Deviation:  0.1487275856622207

# %% [markdown]
# ##Function Testing

# %%
firstcomb = []

for i in range(len(dataarray)):
  B1 = np.sqrt(abs((dataarray[i]["B1_E"])**2 - (dataarray[i]['B1_Px'])**2 - (dataarray[i]['B1_Py'])**2 - (dataarray[i]['B1_Pz'])**2))/1000
  #B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J2 = np.sqrt(abs((dataarray[i]["J1_E"]+dataarray[i]["J2_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J2_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J2_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J2_Pz'])**2))/1000
  #J1J2 = np.sqrt(abs((dataarray[i]["J1_E"])**2 - (dataarray[i]['J1_Px'])**2 - (dataarray[i]['J1_Py'])**2 - (dataarray[i]['J1_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1 + J1J2 - Muon
  if sum < 300:
    firstcomb.append(sum)

firstcombination = np.mean(firstcomb)
#print(firstcomb)
print('Mean: ', firstcombination)
print("Standard Deviation: ", np.std(firstcomb))
          
plt.hist(firstcomb, bins=50, range=(0,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1, J1J2 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.savefig("b1j1j2minusmuon")
plt.show()
# Out:
# Mean:  135.0097339058377
# Standard Deviation:  63.72501015727426

# %% [markdown]
# Combinations to try:
# B1B2 + J1J2 + Muon
# B1B2 + J1J3 + Muon
# B1B2 + J2J3 + Muon

# %%
firstcomb = []
B1B2list = []
J1J2list = []
muonlist = []


for i in range(len(dataarray)):
  #B1B2 = np.sqrt(abs((dataarray[i]["B1_E"])**2 - (dataarray[i]['B1_Px'])**2 - (dataarray[i]['B1_Py'])**2 - (dataarray[i]['B1_Pz'])**2))/1000
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J2 = np.sqrt(abs((dataarray[i]["J1_E"]+dataarray[i]["J2_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J2_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J2_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J2_Pz'])**2))/1000
  #J1J2 = np.sqrt(abs((dataarray[i]["J1_E"])**2 - (dataarray[i]['J1_Px'])**2 - (dataarray[i]['J1_Py'])**2 - (dataarray[i]['J1_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J1J2 + Muon
  if abs(B1B2-80)<40 and abs(J1J2-80)<40:
    B1B2list.append(B1B2)
    J1J2list.append(J1J2)
    muonlist.append(Muon)
  #if 0<sum<250:
    firstcomb.append(sum)

firstcombination = np.mean(firstcomb)
#print(firstcomb)
print('Mean: ', firstcombination)
print("Standard Deviation: ", np.std(firstcomb))
          
plt.hist(firstcomb, bins=25, range=(100,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1B2, J1J2 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  161.46384615506759
# Standard Deviation:  28.785879314915917

# %%
secondcomb = []

for i in range(len(dataarray)):
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J3 = np.sqrt(abs((dataarray[i]["J1_E"]+dataarray[i]["J3_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J3_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J3_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J3_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J1J3 + Muon
  if 100<sum<250:
    secondcomb.append(sum)

secondcombination = np.mean(secondcomb)
#print(secondcomb)
print('Mean: ', secondcombination)
print("Standard Deviation: ", np.std(secondcomb))
          
plt.hist(secondcomb, bins=25, range=(100,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1B2, J1J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  193.45489473768168
# Standard Deviation:  37.86148103427944

# %%
thirdcomb = []

for i in range(len(dataarray)):
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J2J3 = np.sqrt(abs((dataarray[i]["J2_E"]+dataarray[i]["J3_E"])**2 - (dataarray[i]['J2_Px']+dataarray[i]['J3_Px'])**2 - (dataarray[i]['J2_Py']+dataarray[i]['J3_Py'])**2 - (dataarray[i]['J2_Pz']+dataarray[i]['J3_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J2J3 + Muon
  if 100<sum<250:
    thirdcomb.append(sum)

thirdcombination = np.mean(thirdcomb)
#print(thirdcomb)
print('Mean: ', thirdcombination)
print("Standard Deviation: ", np.std(thirdcomb))
          
plt.hist(thirdcomb, bins=25, range=(100,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1B2, J2J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  188.54823902017577
# Standard Deviation:  39.53413236130326

# %% [markdown]
# ##Trying again

# %%
j1 = []
j2 = []
j3 = []
for i in range(len(dataarray)):
  j1.append(np.sqrt(abs(((dataarray[i]["J1_E"])**2 - (dataarray[i]['J1_Px'])**2 - (dataarray[i]['J1_Py'])**2 - (dataarray[i]['J1_Pz'])**2)))/1000)
  j2.append(np.sqrt(abs(((dataarray[i]["J2_E"])**2 - (dataarray[i]['J2_Px'])**2 - (dataarray[i]['J2_Py'])**2 - (dataarray[i]['J2_Pz'])**2)))/1000)
  j3.append(np.sqrt(abs(((dataarray[i]["J3_E"])**2 - (dataarray[i]['J3_Px'])**2 - (dataarray[i]['J3_Py'])**2 - (dataarray[i]['J3_Pz'])**2)))/1000)

# %%
try1 = []
try2 = []
try3 = []
for i in range(len(j1)):
  try1.append(j1[i]+b1b2mean+m23mean+muon_mass)
  try2.append(j2[i]+b1b2mean+m13mean+muon_mass)
  try3.append(j3[i]+b1b2mean+m12mean+muon_mass)

# %%
print('Mean: ', np.mean(try1))
print("Standard Deviation: ", np.std(try1))
plt.hist(try1, bins=70, label="m(T) [GeV]",color="b") 
plt.title("A range of top quark values for a combination of B1B2, J2J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  177.36006315439596
# Standard Deviation:  6.9650612094605835

# %%
print('Mean: ', np.mean(try2))
print("Standard Deviation: ", np.std(try2))
plt.hist(try2, bins=70, label="m(T) [GeV]",color="r") 
plt.title("A range of top quark values for a combination of B1B2, J1J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  176.5135094536995
# Standard Deviation:  4.132609716727437

# %%
print('Mean: ', np.mean(try3))
print("Standard Deviation: ", np.std(try3))
plt.hist(try3, bins=70, label="m(T) [GeV]",color="g") 
plt.title("A range of top quark values for a combination of B1B2, J1J2 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# Mean:  173.85293357318133
# Standard Deviation:  2.3259636691410472
