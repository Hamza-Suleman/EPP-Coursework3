# %% [markdown]
# #Coursework 3

# %% [markdown]
# ##Coursework Code Tests

# %%
# !pip install astropy
from astropy.io import ascii
import numpy as np
from matplotlib import pyplot as plt
import statistics
# Out:
# Requirement already satisfied: astropy in /usr/local/lib/python3.7/dist-packages (4.3.1)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy) (2.0.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from astropy) (1.21.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy) (3.10.0.2)

# %%
dataarray = ascii.read("https://raw.githubusercontent.com/Hamza-Suleman/EPP-Coursework3/main/datafile.csv")
print(dataarray)
# Out:
# Event   mu_E    mu_Px     mu_Py   ...   J3_E    J3_Px    J3_Py     J3_Pz
# ----- -------- -------- --------- ... -------- -------- -------- ---------
#     0  51268.2  23427.4  -30694.4 ...  62572.0 -33733.8 -15020.8  -50334.6
#     8  62607.2 -55928.2  -27403.4 ...  31804.9 -28743.6  11803.6  -203.991
#    41 175318.0 110076.0 -128700.0 ...  68410.5  8936.84  32453.5   59377.2
#    44 125126.0  32677.8  102847.0 ... 112722.0  19212.2 -19288.7 -109245.0
#    52  81170.1  45960.6  -38977.6 ...  55170.7  9476.58 -26691.3   46793.3
#    54  57112.3 -27548.2  -11543.4 ...  77868.8 -13785.2 -22157.4   73276.7
#   100  64891.5 -22903.1  -44698.0 ... 160494.0 -20458.6 -25679.6 -156987.0
#   113  78314.0  22202.4  -56183.6 ...  46334.9  21388.2  13032.1  -38665.0
#   123 190124.0 -81916.9   85738.1 ... 144231.0  32883.8 -13119.1  139745.0
#   131  71425.3 -39384.6   5885.81 ...  38197.5 -31740.0  5191.16  -20362.3
#   ...      ...      ...       ... ...      ...      ...      ...       ...
#  6391  32329.2 -27502.0  -7358.03 ...  38487.6  35261.0  -8031.3   11970.5
#  6454  73422.2  67075.5   15932.9 ... 124565.0 -35074.9 -5837.96  119300.0
#  6466 401410.0 -11086.2   80638.2 ...  72955.2 -280.659  45747.2   55636.9
#  6477 123944.0 -23101.8   30788.6 ...  38922.0  22407.3 -12064.5  -29302.2
#  6500 126025.0  78408.2  -52401.2 ...  89483.5  31982.8 -26125.6   79010.5
#  6583  59438.9 -40544.6  -3789.63 ...  35270.6  4866.95  29195.8  -17997.8
#  6584  68232.5   6250.1  -56522.5 ... 125830.0  6805.78 -33350.4 -120887.0
#  6604  43218.9  34492.7  -25156.8 ...  62774.6 -8356.32  25015.0   56867.1
#  6641  86885.3 -7557.55  -31239.9 ...  99877.4  29600.9  55901.9   77154.9
#  6643  81871.7 -50161.3   36092.5 ...  82555.9  35932.6 -4996.97   73852.6
#  6654  52854.1 -20063.0   48058.8 ...  25931.8  14757.5  20779.0  -2465.46
# Length = 449 rows

# %%
test = []
for i in range(len(dataarray)):
  a = np.sqrt((dataarray[i]["J1_E"]+dataarray[i]["J2_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J2_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J2_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J2_Pz'])**2)/1000
  if abs(a-80)<40:
    test.append(a)
print(np.mean(test))
# Out:
# 81.18074164591046

# %% [markdown]
# ###Calculating m12

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m12 = np.sqrt((line[13]+line[17])**2 - (line[14]+line[18])**2 - (line[15]+line[19])**2 - (line[16]+line[20])**2)/1000

    if abs(m12-80)<40:
            mwlist.append(m12)

m12mean = np.mean(mwlist)
print('Mean: ', m12mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m12mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  81.18074164591046
# Standard Deviation:  15.046417344366949

# %% [markdown]
# ###Calculating m13

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m13 = np.sqrt((line[13]+line[21])**2 - (line[14]+line[22])**2 - (line[15]+line[23])**2 - (line[16]+line[24])**2)/1000

    if abs(m13-80)<40:
            mwlist.append(m13)

m13mean = np.mean(mwlist)
print('Mean: ', m13mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m13mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  81.68432650356482
# Standard Deviation:  15.422884128354791

# %% [markdown]
# ###Calculating m23

# %%
mwlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    m23 = np.sqrt((line[17]+line[21])**2 - (line[18]+line[22])**2 - (line[19]+line[23])**2 - (line[20]+line[24])**2)/1000

    if abs(m23-80)<40:
            mwlist.append(m23)

m23mean = np.mean(mwlist)
print('Mean: ', m23mean)
print("Standard Deviation: ", (statistics.stdev(mwlist)/100)*m23mean)
          
plt.hist(mwlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  78.58913503350712
# Standard Deviation:  15.153927556263104

# %% [markdown]
# ###B1J1

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j1 = np.sqrt((line[5]+line[13])**2 - (line[6]+line[14])**2 - (line[7]+line[15])**2 - (line[8]+line[16])**2)/1000

    if abs(b1j1-80)<40:
            bjlist.append(b1j1)

b1j1mean = np.mean(bjlist)
print('Mean: ', b1j1mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j1mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  90.83047729463615
# Standard Deviation:  17.987816638946153

# %% [markdown]
# ###B1J2

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j2 = np.sqrt((line[5]+line[17])**2 - (line[6]+line[18])**2 - (line[7]+line[19])**2 - (line[8]+line[20])**2)/1000

    if abs(b1j2-80)<40:
            bjlist.append(b1j2)

b1j2mean = np.mean(bjlist)
print('Mean: ', b1j2mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j2mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  91.22513891585919
# Standard Deviation:  17.866354790987412

# %% [markdown]
# ###B1J3

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1j3 = np.sqrt((line[5]+line[21])**2 - (line[6]+line[22])**2 - (line[7]+line[23])**2 - (line[8]+line[24])**2)/1000

    if abs(b1j3-80)<40:
            bjlist.append(b1j3)

b1j3mean = np.mean(bjlist)
print('Mean: ', b1j3mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b1j3mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  84.54153630588095
# Standard Deviation:  17.48440626508665

# %% [markdown]
# ###B2J1

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j1 = np.sqrt((line[9]+line[13])**2 - (line[10]+line[14])**2 - (line[11]+line[15])**2 - (line[12]+line[16])**2)/1000

    if abs(b2j1-80)<40:
            bjlist.append(b2j1)

b2j1mean = np.mean(bjlist)
print('Mean: ', b2j1mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j1mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  90.56881516259845
# Standard Deviation:  18.252261505498097

# %% [markdown]
# ###B2J2

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j2 = np.sqrt((line[9]+line[17])**2 - (line[10]+line[18])**2 - (line[11]+line[19])**2 - (line[12]+line[20])**2)/1000

    if abs(b2j2-80)<40:
            bjlist.append(b2j2)

b2j2mean = np.mean(bjlist)
print('Mean: ', b2j2mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j2mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  85.62474233223087
# Standard Deviation:  18.102068393210754

# %% [markdown]
# ###B2J3

# %%
bjlist = []

for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b2j3 = np.sqrt((line[9]+line[21])**2 - (line[10]+line[22])**2 - (line[11]+line[23])**2 - (line[12]+line[24])**2)/1000

    if abs(b2j3-80)<40:
            bjlist.append(b2j3)

b2j3mean = np.mean(bjlist)
print('Mean: ', b2j3mean)
print("Standard Deviation: ", (statistics.stdev(bjlist)/100)*b2j3mean)
          
plt.hist(bjlist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# Mean:  80.62244065022391
# Standard Deviation:  16.73753717132416

# %% [markdown]
# ###B1B2

# %%
bblist = []
print(bblist)
for line in dataarray:
    # 3 possibilities to pair  2 light jets:

    b1b2 = np.sqrt((line[5]+line[9])**2 - (line[6]+line[10])**2 - (line[7]+line[11])**2 - (line[8]+line[12])**2)/1000

    if abs(b1b2-80)<40:
            bblist.append(b1b2)

b1b2mean = np.mean(bblist)
print('Mean: ', b1b2mean)
print("Standard Deviation: ", (statistics.stdev(bblist)/100)*b1b2mean)
          
plt.hist(bblist, bins=20, range=(40,120), label="m(W) [GeV]") 
plt.xlabel("m(W) [GeV]")
plt.savefig('MW.png')
plt.show()
# Out:
# []
# Mean:  86.40246153365707
# Standard Deviation:  17.071979226406135

# %% [markdown]
# ###Muon Mass

# %%
muon_mass_list = []
for i in range(len(dataarray)):
  a = np.sqrt(abs(((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2)/1000))
  muon_mass_list.append(a)
muon_mass = np.mean(muon_mass_list)
print("Muon Mass: ", muon_mass)
print("Standard Deviation: ", (statistics.stdev(muon_mass_list)/100)*muon_mass)
# Out:
# Muon Mass:  5.940379163577887
# Standard Deviation:  0.2796983198460747

# %% [markdown]
# ###Top Quark Mass

# %%
jet_mass = m12mean+m13mean+m23mean
print(jet_mass)
# Out:
# 241.4542031829824

# %%
b_j_mass = b1b2mean + (jet_mass/3)
print(b_j_mass)
# Out:
# 166.88719592798455

# %%
top_mass = b_j_mass + muon_mass
print(top_mass)
print()
# Out:
# 172.82757509156244

# %%
print(m12mean-muon_mass+b1b2mean)
# Out:
# 161.64282401598965

# %%
print(m13mean-muon_mass+b1b2mean)
# Out:
# 162.14640887364402

# %%
print(m23mean-muon_mass+b1b2mean)
# Out:
# 159.0512174035863

# %%
print(b1j1mean+muon_mass)
# Out:
# 96.77085645821404

# %%
print(m12mean+b1b2mean)
# Out:
# 167.58320317956753

# %%
print(m13mean+b1b2mean)
# Out:
# 168.08678803722188

# %%
print(m23mean+b1b2mean)
# Out:
# 164.9915965671642

# %%
print(b1j1mean+b1j2mean+b1j3mean)
# Out:
# 266.5971525163763

# %%
print(b1b2mean+m12mean+muon_mass)
# Out:
# 173.52358234314542

# %%
print(b1b2mean+m13mean+muon_mass)
# Out:
# 174.02716720079977

# %%
print(b1b2mean+m23mean+muon_mass)
# Out:
# 170.9319757307421

# %% [markdown]
# ##Function

# %% [markdown]
# Combinations to try:
# B1B2 + J1J2 + Muon
# B1B2 + J1J3 + Muon
# B1B2 + J2J3 + Muon

# %%
firstcomb = []

for i in range(len(dataarray)):
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J2 = np.sqrt(abs((dataarray[i]["J1_E"]+dataarray[i]["J2_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J2_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J2_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J2_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J1J2 + Muon
  if 100<sum<250:
    firstcomb.append(sum)

firstcombination = np.mean(firstcomb)
print(firstcomb)
print('Mean: ', firstcombination)
print("Standard Deviation: ", statistics.stdev(firstcomb))
          
plt.hist(firstcomb, bins=25, range=(100,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1B2, J1J2 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# [245.55316155145346, 111.84415014452455, 229.90407140837831, 238.69952850084093, 148.45099926773753, 197.25473455187858, 220.34555842247195, 240.2844519586679, 182.26021560282788, 178.10618216447915, 173.29684019217012, 196.24179166250775, 211.67261608571243, 153.7367975818199, 107.08574079793239, 219.0231422812713, 157.5678642963411, 221.35124927148948, 197.6444271987725, 126.05281072246117, 111.79795718632867, 144.1505756206222, 203.28115902657782, 223.83294556509333, 173.72429204942208, 130.04315382108055, 180.65577838425162, 165.73175733909787, 218.29030314736528, 202.38550329310044, 126.05538910118348, 150.03820430690584, 182.6045048758032, 136.38311299466295, 242.4833613271154, 241.43733204456979, 147.63324689749575, 167.3628530650068, 164.19655507472098, 243.95207489387548, 128.7344556372021, 210.68277386822575, 221.46459081907713, 188.3764217087052, 193.28989190967357, 128.98785165104604, 167.19608649197383, 116.63238507950109, 241.03986435178243, 218.40687032170072, 106.16250907559444, 220.7851718911609, 249.032716050935, 205.98711904117988, 140.48428381088394, 142.0745496037084, 115.73055921922712, 218.74070114788967, 237.36780099469735, 193.4649831176304, 188.19033781965155, 151.49211058781376, 186.5440378966117, 181.6241409139378, 205.01911159184294, 159.3708139867381, 231.7966462870004, 207.14684533708564, 117.87462424616731, 237.21915837185773, 220.26983572857753, 173.39532662029498, 187.2761455783574, 145.5347931076852, 193.58893724824384, 224.63315233655632, 227.32232390866014, 240.2403179658416, 200.39383697366196, 133.46288334812357, 220.07375450566119, 131.36515650720352, 225.66050909622416, 168.62105771658503, 228.27304800178277, 167.85893170213006, 241.91276276191357, 108.19534975213989, 214.56858558795943, 193.79300850729956, 194.82131237610602, 189.78705239781354, 172.52703637853742, 167.18518959182802, 166.0694617183896, 227.02048268898466, 210.50088438674558, 148.27608348862523, 204.59199630435208, 123.85107023747386, 166.43349238960548, 231.96964572075166, 239.78451890069098, 157.34747963896484, 150.5273599995485, 146.04515894081135, 234.24068900350338, 231.62007244975194, 227.79280007469382, 243.23336074754476, 162.1725418438159, 181.11082156896052, 116.13336198485945, 130.8924539901489, 203.21696337656428, 226.52787433609188, 248.85446808282714, 191.69433163323976, 137.02490252936371, 130.6752255105403, 187.9480731922925, 204.73535538725937, 137.78461545707108, 125.08895325595216, 160.16239626363793, 222.32612462590762, 121.05993519519643, 187.0584574101383, 182.52038335248372, 133.3317238552194, 176.9349432231783, 106.58896715329789, 224.4267147898019, 225.6541635873567, 218.97344780456802, 199.86218458067265, 197.19330436616903, 241.07708307061716, 220.64366705487336, 201.21970051961637, 232.98903948983198, 206.23110359694044, 248.64670813790013, 232.06691915208424, 229.312964265776, 175.9416946215861, 188.52839710491835, 197.2203179805884, 200.40354565395376, 197.9529715603912, 238.3613897742467, 148.7094173467363, 212.7820988645326, 239.22769428451542, 180.27384351539698, 146.04887729686925, 202.27978804596745, 143.84391980870953]
# Mean:  186.8804715215241
# Standard Deviation:  40.14445453952604

# %%
secondcomb = []

for i in range(len(dataarray)):
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J3 = np.sqrt(abs((dataarray[i]["J1_E"]+dataarray[i]["J3_E"])**2 - (dataarray[i]['J1_Px']+dataarray[i]['J3_Px'])**2 - (dataarray[i]['J1_Py']+dataarray[i]['J3_Py'])**2 - (dataarray[i]['J1_Pz']+dataarray[i]['J3_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J1J2 + Muon
  if 100<sum<250:
    secondcomb.append(sum)

secondcombination = np.mean(secondcomb)
print(secondcomb)
011711363297, 215.6670991656553, 132.40531086229907, 224.47382195761378, 202.3779217485444, 117.24026256852913, 162.82722368327944, 198.12577033259132, 103.1064505136924, 209.16375157439072, 116.46391080529067, 170.80231617210785, 233.7125408763025, 145.441253025842, 200.1953431849093, 109.4484808554842, 197.05388239069143, 193.33167028580888, 125.42313515114125, 189.05195285772035, 246.7043267172722, 138.90477452113825, 222.96248102759705, 179.27568221720037, 147.68492062750317, 200.86454631727884, 175.91036559665937, 137.1329090292872, 147.51166003690307, 202.41690906917694, 212.04908428380742, 150.02678719714228, 127.00509686557771, 233.43896041861956, 115.2144112953479, 151.91037383824747, 143.41620870691665, 106.79082824713745, 121.76175660814147, 199.09846029760487, 178.00820946769855, 220.5747814444089, 174.1602594176097, 205.9406485791643, 193.53861012981747, 130.4640164781208, 249.28649958641805, 226.0301400980382, 237.08695815774334, 152.42412017631722, 107.0017021370305, 167.314627661347 ...
# Mean:  166.84481683218493
# Standard Deviation:  40.96640532900122

# %%
thirdcomb = []

for i in range(len(dataarray)):
  B1B2 = np.sqrt(abs((dataarray[i]["B1_E"]+dataarray[i]["B2_E"])**2 - (dataarray[i]['B1_Px']+dataarray[i]['B2_Px'])**2 - (dataarray[i]['B1_Py']+dataarray[i]['B2_Py'])**2 - (dataarray[i]['B1_Pz']+dataarray[i]['B2_Pz'])**2))/1000
  J1J3 = np.sqrt(abs((dataarray[i]["J2_E"]+dataarray[i]["J3_E"])**2 - (dataarray[i]['J2_Px']+dataarray[i]['J3_Px'])**2 - (dataarray[i]['J2_Py']+dataarray[i]['J3_Py'])**2 - (dataarray[i]['J2_Pz']+dataarray[i]['J3_Pz'])**2))/1000
  Muon = np.sqrt(abs((dataarray[i]["mu_E"])**2 - (dataarray[i]['mu_Px'])**2 - (dataarray[i]['mu_Py'])**2 - (dataarray[i]['mu_Pz'])**2))/1000
  sum = B1B2 + J1J2 + Muon
  if 100<sum<250:
    thirdcomb.append(sum)

thirdcombination = np.mean(thirdcomb)
print(thirdcomb)
print('Mean: ', thirdcombination)
print("Standard Deviation: ", statistics.stdev(thirdcomb))
          
plt.hist(thirdcomb, bins=25, range=(100,250), label="m(T) [GeV]") 
plt.title("A range of top quark values for a combination of B1B2, J2J3 and a Muon")
plt.ylabel("Arbitrary Units")
plt.xlabel("m(T) [GeV]")
plt.show()
# Out:
# [167.54738427121885, 202.33302835452957, 226.34931047623792, 149.9378562651085, 104.67939568995838, 176.01067461816896, 210.21021342592348, 154.3267107260917, 162.70109388482382, 198.91179493924344, 233.17688766955843, 114.69264819679154, 158.5304067305676, 139.48695369296726, 202.27985698909904, 165.25289644597933, 112.34817445843743, 190.04757485209788, 171.80148424852894, 187.7839002535644, 138.61539198436608, 156.6484246837834, 133.40340528811066, 199.87702162624197, 133.89009468593392, 130.99334800226268, 153.06247473472013, 173.53120394498725, 132.4391087731345, 127.59846638958179, 207.93261159463188, 125.02134603487879, 131.39943781198514, 181.46155364216315, 178.61490089125095, 190.49530925266916, 233.0574621891128, 216.3